# %% [markdown]
# <span style="color:red;font-weight:bold">Jayant Solanki</span>
# <hr/>
# ## <span style="float:left">Finding trending words from a news topic in NYTimes website.</span>
# ### <span style="float:right">Using nytimes articles API to fetch articles for a particular search topic</span>
# <hr/>

# %%
#Background: The nytimes api doesn't returns full article body, just the snippet of it each returned
# so, I have to write the code to fetch the weburl for each article, then perfrom further requests to those url and 
#fetch the story body of each article
import requests # for performing html request to nytimes API
from datetime import datetime
from time import sleep
import lxml.html as html # for scrapping the content of the article URL of nytimes
import json

# %%
# Each API keys can provide 10000 response hits
topic = "trade+war"#topic to be looked for
apikey = "527c18ffc4e648cb936f582a0e264ff1"
fl = "snippet,web_url"#selective attributes of json response
pageNo = "0"#initial page is 0, articles fetched using api are grouped in 10 per page starting 0 and upto page 100
dateRange = ["20180331", "20180401", "20180402", "20180403", "20180404", "20180405", "20180406", "20180407"]# can be changed t any period

# %%
#this function parse the json response from nytimes and create new dictionary using two attributes only
def parse_articles(articles):
    '''
    This function takes in a response to the NYT api and parses
    the articles into a list of dictionaries
    '''
    news = []
    fetch = articles['response']['docs']
    for i in range(0,len(fetch)):
        dic = {}
#         print(fetch[i])
        dic['web_url'] = fetch[i]['web_url']
        if fetch[i]['snippet'] is not None:
            dic['snippet'] = fetch[i]['snippet']
#         dic['url'] = i['web_url']
        news.append(dic)
    return(news)

# %%
# this function perfrom request to nytimes api using the paramters passed and returns the parseed responsed to the caller function
def get_articles(topic, begin_date, end_date, fl, apikey):
    all_articles = []#stores all articles for a particular day
    page = 0
    while(page<100):
        sleep(1)
#     for page in range(0,100): #NYT limits pages to first 100 pages starting page 0, each page has 10 articles max
        try:
            
            url = "http://api.nytimes.com/svc/search/v2/articlesearch.json?q="+topic+"&begin_date="+begin_date+"&end_date="+end_date+"&fl="+fl+"&page="+str(page)+"&api-key="+apikey
            print(url)
            requestArticles = requests.get(url)
            data = requestArticles.json()
            if len(data["response"]["docs"])>0:
                all_articles.append(parse_articles(data))
#                 print(data)
            else:# checks if further pages have no articles to show, if yes then break the loop and return the fetched articles
                print(parse_articles(data))
                break
        except:
            print("You called the api way to fast, Dude, trying again")
            print(data)
#             page = page - 1
            sleep(1)
            continue#try again
        print("Page: "+str(page))
#         break
        page=page+1
    return(all_articles)

# %%
#caller function
processArticles = []
for i in range(0,7):
    datetimeobject = datetime.strptime(dateRange[i],'%Y%m%d')
    beginDate = datetimeobject.strftime('%m-%d-%Y')
    datetimeobject = datetime.strptime(dateRange[i+1],'%Y%m%d')
    endDate = datetimeobject.strftime('%m-%d-%Y')
    print("Fetching articles for Data period: " + beginDate + " - "+ endDate)
    processArticles = get_articles(topic, dateRange[i], dateRange[i+1],fl, apikey)
    if(len(processArticles)>0):
#         try:
#             dataToWrite = processArticles
# #             print(dataToWrite)
#         except:
#             print(len(processArticles))
#             print(processArticles)
#             print(processArticles[0])
#             break
        with open("textcorpus/"+topic+dateRange[i]+".txt", 'w') as outfile:#used for storing snippets
            for item in processArticles:
                for articles in item:
#                     print(articles)
                    outfile.write(articles["snippet"])
                    outfile.write("\n")
        with open("textcorpus/"+topic+dateRange[i]+"-full.txt", 'w') as outfile:#used for storing full articles
            for item in processArticles:
                for articles in item:
                    fullpage = requests.get(articles["web_url"])
                    htmlbody = html.fromstring(requests.get(articles["web_url"]).content)
                    output = "".join(htmlbody.xpath('//p[contains(@class,"story-body-text")]//text()'))#scrapper
#                     print(output+"\n\n")
#                     output = output.decode('utf8').encode('latin1').decode('utf8')
                    output = str(output.encode("ascii", "ignore"))#since the body has lots of escape characters, I have to convert
    # utf-8 response into ascii using ignore flag to bypass those escape characters
                    outfile.write(output[2:-1])
                    outfile.write("\n")
    else:
        print("Insufficient data for date: "+beginDate+" to save")
#     break
# print(processArticles[0][0:-1])
# Out:
# Fetching articles for Data period: 03-31-2018 - 04-01-2018
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180331&end_date=20180401&fl=snippet,web_url&page=0&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180331&end_date=20180401&fl=snippet,web_url&page=1&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180331&end_date=20180401&fl=snippet,web_url&page=2&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180331&end_date=20180401&fl=snippet,web_url&page=3&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180331&end_date=20180401&fl=snippet,web_url&page=4&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180331&end_date=20180401&fl=snippet,web_url&page=5&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180331&end_date=20180401&fl=snippet,web_url&page=6&api-key=527c18ffc4e648cb936f582a0e264ff1
# []
# Fetching articles for Data period: 04-01-2018 - 04-02-2018
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180401&end_date=20180402&fl=snippet,web_url&page=0&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180401&end_date=20180402&fl=snippet,web_url&page=1&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180401&end_date=20180402&fl=snippet,web_url&page=2&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180401&end_date=20180402&fl=snippet,web_url&page=3&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180401&end_date=20180402&fl=snippet,web_url&page=4&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180401&end_date=20180402&fl=snippet,web_url&page=5&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180401&end_date=20180402&fl=snippet,web_url&page=6&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180401&end_date=20180402&fl=snippet,web_url&page=7&api-key=527c18ffc4e648cb936f582a0e264ff1
# []
# Fetching articles for Data period: 04-02-2018 - 04-03-2018
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=0&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=1&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=2&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=3&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=4&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=5&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=6&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=7&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=8&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=9&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 9
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=10&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 10
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=11&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 11
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=12&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 12
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180402&end_date=20180403&fl=snippet,web_url&page=13&api-key=527c18ffc4e648cb936f582a0e264ff1
# []
# Fetching articles for Data period: 04-03-2018 - 04-04-2018
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=0&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=1&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=2&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=3&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=4&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=5&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=6&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=7&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=8&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=9&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 9
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=10&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 10
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=11&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 11
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=12&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 12
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=13&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 13
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=14&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 14
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180403&end_date=20180404&fl=snippet,web_url&page=15&api-key=527c18ffc4e648cb936f582a0e264ff1
# []
# Fetching articles for Data period: 04-04-2018 - 04-05-2018
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=0&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=1&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=2&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=3&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=4&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=5&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=6&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=7&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=8&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=9&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 9
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=10&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 10
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=11&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 11
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=12&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 12
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=13&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 13
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=14&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 14
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=15&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 15
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=16&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 16
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=17&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 17
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=18&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 18
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=19&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 19
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=20&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 20
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180404&end_date=20180405&fl=snippet,web_url&page=21&api-key=527c18ffc4e648cb936f582a0e264ff1
# []
# Fetching articles for Data period: 04-05-2018 - 04-06-2018
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=0&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=1&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=2&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=3&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=4&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=5&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=6&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=7&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=8&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=9&api-key=527c18ffc4e648cb936f582a0e264ff1
# You called the api way to fast, Dude, trying again
# {'message': 'An unexpected error occurred'}
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=9&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 9
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=10&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 10
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=11&api-key=527c18ffc4e648cb936f582a0e264ff1
# You called the api way to fast, Dude, trying again
# {'status': 'OK', 'copyright': 'Copyright (c) 2018 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/aponline/2018/04/05/us/ap-facebook-privacy-scandal-investigations-glance.html', 'snippet': 'Facebook CEO Mark Zuckerberg will testify before Congress next week. His appearance comes as authorities around the world investigate allegations that the political data-mining firm Cambridge Analytica inappropriately accessed data on as many as 8...', 'score': 0.000222463}, {'web_url': 'https://www.nytimes.com/reuters/2018/04/05/sports/soccer/05reuters-soccer-libya.html', 'snippet': 'Libya are hoping a three-day visit by a FIFA delegation will lead to a lifting of the ban on hosting international football matches in the strife-torn country.', 'score': 0.00022173866}, {'web_url': 'https://www.nytimes.com/reuters/2018/04/05/world/europe/05reuters-britain-russia-ambassador-skripals.html', 'snippet': "Russia's ambassador to Britain, Alexander Yakovenko, said on Thursday he was happy to hear that Yulia Skripal, the daughter of former Russian double agent Sergei Skripal, was recovering after she was poisoned a month ago in England.", 'score': 0.00021854733}, {'web_url': 'https://www.nytimes.com/aponline/2018/04/05/world/americas/ap-lt-mexico-us-border.html', 'snippet': "Mexican politicians put aside differences Thursday to condemn U.S. President Donald Trump's decision to deploy National Guard troops to the border.", 'score': 0.00019768486}, {'web_url': 'https://www.nytimes.com/reuters/2018/04/05/business/05reuters-facebook-privacy-shares.html', 'snippet': 'Shares of Facebook Inc rose as much as 4.2 percent on Thursday after Chief Executive Officer Mark Zuckerberg said the social network had not seen any meaningful impact on usage or ad sales in the wake of a data privacy scandal.', 'score': 0.00019760193}, {'web_url': 'https://www.nytimes.com/reuters/2018/04/05/business/05reuters-spotify-ipo-investors.html', 'snippet': "The buzzy debut of Spotify Technology SA on the New York Stock Exchange on Tuesday drew retail investors across generations, not just the Millennials who make up the largest proportion of the music streaming service's customer base, retail brokera...", 'score': 0.0001941453}, {'web_url': 'https://www.nytimes.com/aponline/2018/04/05/world/middleeast/ap-ml-bahrain-uk-military-base.html', 'snippet': 'Britain opened its first permanent military base in the Middle East in more than four decades on Thursday in the Persian Gulf country of Bahrain, giving the U.K. an expansive presence along key international shipping routes.', 'score': 0.0001937469}, {'web_url': 'https://www.nytimes.com/reuters/2018/04/05/world/americas/05reuters-usa-immigration-mexico.html', 'snippet': 'Mexican President Enrique Pena Nieto on Thursday sharply rebuked Donald Trump over his plan to send National Guard troops to the border, joining with opponents to tell the U.S. leader not to vent his domestic political "frustration" on Mexico.', 'score': 0.00019321589}, {'web_url': 'https://www.nytimes.com/2018/04/05/sports/basketball/kyrie-irving-celtics-knee-surgery.html', 'snippet': 'His knee injury is a big blow to Boston, which had hopes of contending for the championship. That now seems highly unlikely.', 'score': 0.00019257123}, {'web_url': 'https://www.nytimes.com/2018/04/05/opinion/facebook-social-media.html', 'snippet': 'A lobbying group for the tech companies calls for perspective, and readers discuss the issue of privacy.', 'score': 0.00019237651}], 'meta': {'hits': 176, 'offset': 100, 'time': 12}}}
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=11&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 11
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=12&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 12
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=13&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 13
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=14&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 14
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=15&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 15
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=16&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 16
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=17&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 17
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180405&end_date=20180406&fl=snippet,web_url&page=18&api-key=527c18ffc4e648cb936f582a0e264ff1
# []
# Fetching articles for Data period: 04-06-2018 - 04-07-2018
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=0&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 0
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=1&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 1
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=2&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 2
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=3&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 3
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=4&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 4
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=5&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 5
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=6&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 6
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=7&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 7
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=8&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 8
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=9&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 9
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=10&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 10
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=11&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 11
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=12&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 12
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=13&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 13
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=14&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 14
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=15&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 15
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=16&api-key=527c18ffc4e648cb936f582a0e264ff1
# Page: 16
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=trade+war&begin_date=20180406&end_date=20180407&fl=snippet,web_url&page=17&api-key=527c18ffc4e648cb936f582a0e264ff1
# []

# %%
# /usr/local/hadoop/bin/hadoop jar /usr/local/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.8.3.jar -input /user/jayant/input/ -output /user/jayant/output_new2 -mapper /home/jayant/wordcount_mapper.py -reducer /home/jayant/wordcount_reducer.py -numReduceTasks 1
